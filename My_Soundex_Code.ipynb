# %% [markdown]
# <a href="https://colab.research.google.com/github/EshraqAllawama/Libraries-in-PYTHON/blob/main/My_Soundex_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def remove_(l):
 o = []
 lo = []

 o.append(l[0])
 for i in range(len(l)-1):
    if l[i] != l[i+1]:
       o.append(l[i+1])

 for k in range(len(o)):
    if o[k] != 0:
       lo.append(o[k])
 return lo

def f_1(l):
  m = l
  if len(l) == 3:
     m = l
  elif len(l)>3:
     p = len(l)-3
     for i in range(p):
         l.pop()
     m = l
  else :
     p = 3-len(l)
     for i in range(p):
         m.append(0)
     m = l
  return m

def f_2(m,t_0):
  y =""
  for c in m:
      y += str(c)

  if t_0 == t_0.upper():
    print(t_0+y)
  else:
    print(t_0.upper()+y)

def solv(t_0,t_1):
  l = []
  chr = {
    0:["A","E","I","O","Y","H","W","U"],
    1:["P","B","F","V"],
    2:["C","G","K","J","Q","X","S","Z"],
    3:["D","T"],
    4:["L"],
    5:["M","N"],
    6:["R"]
        }
  for i in t_1:
     for j,k in chr.items():
         if i in k or i.upper() in k:
            l.append(j)
  l = remove_(l)
  m = f_1(l)
  f_2(m,t_0)

def Sdx(word):
 t_0 = word[0]
 t_1 = word[1:len(word)]
 solv(t_0,t_1)

# %%
#Enter Your word to find soundex code for it
Sdx(input())
